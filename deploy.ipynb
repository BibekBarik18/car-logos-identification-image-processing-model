# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import load_model
import keras
import numpy as np

# %%
img=cv2.imread(r"C:\Users\bmbar\Pictures\Screenshots\Screenshot 2024-02-17 221429.png")

# %%
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img=cv2.resize(img,(128,128))
img=np.array(img)

img=img.astype('float64')

# %%
img=img.reshape((1,128,128,3))
img.shape
# Out:
# (1, 128, 128, 3)

# %%
model=load_model(r"D:\GIT\car_logo_identification_project\car_logo_detection1.h5")

# %%
import os

cwd=os.getcwd()
print(cwd)
# Out:
# d:\GIT\car_logo_identification_project

# %%
prediction=model.predict(img)
# Out:
# 1/1 [==============================] - 0s 316ms/step

# %%
type(prediction)
# Out:
# numpy.ndarray

# %%
k=prediction.flatten()

# %%
print(k)
p=np.where(k==1)[0]
# Out:
# [0. 0. 0. 1. 0. 0. 0. 0.]

# %%
if(p==0):
    print("hyndai")
elif(p==1):
    print("lexus")
elif(p==2):
    print("mazda")
elif(p==3):
    print("mercedes")
elif(p==4):
    print("opel")
elif(p==5):
    print("skoda")
elif(p==6):
    print("toyota")
elif(p==7):
    print("volkswagen")
# Out:
# mercedes
